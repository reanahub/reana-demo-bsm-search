# %%
# %pylab inline
import json
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = np.array([[x['region'],x['var']] for x in json.load(open('./data.json'))])

# %%
_=plt.hist(data[data[:,0] == 1][:,1], bins = np.linspace(-5,5,101), histtype='stepfilled')

# %%
_=plt.hist(data[data[:,0] == 0][:,1], bins = np.linspace(-5,5,51), histtype='stepfilled')
